# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Country Name Country Code                               Indicator Name  \
# 0        Aruba          ABW  Electric power consumption (kWh per capita)
# 1  Afghanistan          AFG  Electric power consumption (kWh per capita)
# 2       Angola          AGO  Electric power consumption (kWh per capita)
# 3      Albania          ALB  Electric power consumption (kWh per capita)
# 4      Andorra          AND  Electric power consumption (kWh per capita)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 0  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 1  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 2  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 3  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#           2010         2011         2012         2013         2014  2015  \
# 0          NaN          NaN          NaN          NaN          NaN   NaN
# 1          NaN          NaN          NaN          NaN          NaN   NaN
# 2   206.340578   207.031259   219.356355   280.402518   312.476017   NaN
# 3  1943.343354  2205.703920  2118.327776  2533.252829  2309.366503   NaN
# 4          NaN          NaN          NaN          NaN          NaN   NaN
#
#    2016  2017  2018  Unnamed: 63
# 0   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN          NaN
#
# [5 rows x 64 columns]

# %%
df=df_data_1.set_index('Country Name')

# %%
body = client_14a9f9701e13487fa2f38574727c855a.get_object(Bucket='capstoneprojectcoursera-donotdelete-pr-50vxupoab8kolq',Key='Metadata_Country_API_EG.USE.ELEC.KH.PC_DS2_en_csv_v2_10577425.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  Central Bureau of Statistics and Central Bank ...        Aruba         NaN
# 1  Central Statistics Organization; World Bank st...  Afghanistan         NaN
# 2  IMF ; Source of population estimates: UN Popul...       Angola         NaN
# 3  Albanian Institute of Statistics ; Source of p...      Albania         NaN
# 4  Government of Andorra, Department of Statistic...      Andorra         NaN

# %%
body = client_14a9f9701e13487fa2f38574727c855a.get_object(Bucket='capstoneprojectcoursera-donotdelete-pr-50vxupoab8kolq',Key='SE4ALLData.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_3 = pd.read_csv(body)
df_data_3.head()
# Out:
#   Country Name Country Code  \
# 0  BES Islands          BES
# 1  BES Islands          BES
# 2  BES Islands          BES
# 3  BES Islands          BES
# 4  BES Islands          BES
#
#                                       Indicator Name  \
# 0  Access to Clean Fuels and Technologies for coo...
# 1  Access to electricity (% of rural population w...
# 2      Access to electricity (% of total population)
# 3  Access to electricity (% of urban population w...
# 4  Energy intensity level of primary energy (MJ/2...
#
#                  Indicator Code  1990  1991  1992  1993  1994  1995  \
# 0            2.1_ACCESS.CFT.TOT   NaN   NaN   NaN   NaN   NaN   NaN
# 1  1.2_ACCESS.ELECTRICITY.RURAL   NaN   NaN   NaN   NaN   NaN   NaN
# 2    1.1_ACCESS.ELECTRICITY.TOT   NaN   NaN   NaN   NaN   NaN   NaN
# 3  1.3_ACCESS.ELECTRICITY.URBAN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  6.1_PRIMARY.ENERGY.INTENSITY   NaN   NaN   NaN   NaN   NaN   NaN
#
#       ...       2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0     ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     ...        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    Unnamed: 31
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 32 columns]

# %%
df_data_3.groupby(['Indicator Name','Indicator Code']).sum()
# Out:
#                                                                                            1990  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.158844e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.390779e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.681840e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.518059e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.297296e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.233285e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              3.983409e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.413224e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.186572e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.333944e+08
#
#                                                                                            1991  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.167224e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.400649e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.687869e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.535024e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.334057e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.298475e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.054526e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.476020e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.213675e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.353980e+08
#
#                                                                                            1992  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.181268e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.414570e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.699180e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.575224e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.346391e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.290746e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.108173e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.608682e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.224889e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.336374e+08
#
#                                                                                            1993  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.176108e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.425172e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.706518e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.570641e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.480837e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.443682e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.148655e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.634583e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.253906e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.357550e+08
#
#                                                                                            1994  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.198999e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.445489e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.723079e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.557142e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.509950e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.493574e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.174914e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.642237e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.284763e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.359798e+08
#
#                                                                                            1995  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.233390e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.487300e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.772397e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.551715e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.635481e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.403417e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.280172e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.691212e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.328794e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.410790e+08
#
#                                                                                            1996  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.255137e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.513057e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.780665e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.512249e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.674050e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.392511e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.340677e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.631866e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.371032e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.446741e+08
#
#                                                                                            1997  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.263104e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.523964e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.790494e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.453730e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.713664e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.203774e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.377141e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.522892e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.400160e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.463676e+08
#
#                                                                                            1998  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.277585e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.538532e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.798490e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.431530e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.734697e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.081364e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.423638e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.450215e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.436788e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.468761e+08
#
#                                                                                            1999  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                       NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.288824e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.552153e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.805721e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.404144e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    2.758611e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.201867e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              4.551056e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.450604e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  1.478072e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   2.510683e+08
#
#                                                                                       ...       \
# Indicator Name                                     Indicator Code                     ...
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                 ...
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL       ...
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT         ...
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN       ...
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY       ...
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT       ...
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY        ...
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION                 ...
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC         ...
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT     ...
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM      ...
#
#                                                                                            2008  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              1.165683e+04
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.454868e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.710575e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.924784e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.203197e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    3.756016e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.221028e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              5.246127e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.362213e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  2.023841e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   3.079892e+08
#
#                                                                                            2009  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              1.176170e+04
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.464796e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.721987e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.936606e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.198441e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    3.899254e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.289638e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              5.326383e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.368732e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  2.016371e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   3.041988e+08
#
#                                                                                            2010  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              1.186735e+04
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.471998e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.719850e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.928207e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.190468e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    4.214746e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.464917e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              5.514981e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.361381e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  2.150188e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   3.196452e+08
#
#                                                                                            2011  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              1.196339e+04
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.487120e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.747550e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.956494e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.166999e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    4.437319e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.380813e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              5.590836e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.308047e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  2.219931e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   3.248972e+08
#
#                                                                                            2012  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              1.205428e+04
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.512883e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.763600e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.963408e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.144941e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    4.754868e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.498034e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              5.750317e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.322307e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  2.270234e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   3.290662e+08
#
#                                                                                            2013  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              1.214387e+04
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.524959e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.774735e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.969045e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.126035e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    5.087462e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.715741e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              5.931312e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.382713e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  2.337551e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   3.351485e+08
#
#                                                                                            2014  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              1.222953e+04
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.541246e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.792089e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.979430e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.088715e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    5.356734e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.758310e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              6.051760e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.348710e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  2.381826e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   3.386844e+08
#
#                                                                                            2015  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              1.228915e+04
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    1.557014e+04
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      1.805275e+04
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    1.989281e+04
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY    1.039911e+03
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT    5.547803e+06
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY     6.783387e+03
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION              6.164421e+07
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC      6.304170e+03
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT  2.427539e+07
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM   3.414803e+08
#
#                                                                                            2016  \
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT              12367.050000
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL    15753.819475
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT      18213.324861
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN    19989.718915
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY             NaN
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT             NaN
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY              NaN
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION                       NaN
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC               NaN
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT           NaN
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM            NaN
#
#                                                                                    Unnamed: 31
# Indicator Name                                     Indicator Code
# Access to Clean Fuels and Technologies for cook... 2.1_ACCESS.CFT.TOT                      NaN
# Access to electricity (% of rural population wi... 1.2_ACCESS.ELECTRICITY.RURAL            NaN
# Access to electricity (% of total population)      1.1_ACCESS.ELECTRICITY.TOT              NaN
# Access to electricity (% of urban population wi... 1.3_ACCESS.ELECTRICITY.URBAN            NaN
# Energy intensity level of primary energy (MJ/20... 6.1_PRIMARY.ENERGY.INTENSITY            NaN
# Renewable electricity output (GWh)                 4.1.2_REN.ELECTRICITY.OUTPUT            NaN
# Renewable electricity share of total electricit... 4.1_SHARE.RE.IN.ELECTRICITY             NaN
# Renewable energy consumption (TJ)                  3.1_RE.CONSUMPTION                      NaN
# Renewable energy share of TFEC (%)                 2.1_SHARE.TOTAL.RE.IN.TFEC              NaN
# Total electricity output (GWh)                     4.1.1_TOTAL.ELECTRICITY.OUTPUT          NaN
# Total final energy consumption (TFEC) (TJ)         1.1_TOTAL.FINAL.ENERGY.CONSUM           NaN
#
# [11 rows x 28 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
years=list(map(str,range(1960,2015)))
df.loc['India',years].plot(kind='line')

# %%
df.loc['India','China'].[years].plot(kind='bar')
# Out:
#   File "<ipython-input-40-4772a821ac37>", line 1
#     df.loc['India','China'].[years].plot(kind='bar')
#                             ^
# SyntaxError: invalid syntax

# %%
df.loc[['India','China']]
# Out:
#              Country Code                               Indicator Name  \
# Country Name
# India                 IND  Electric power consumption (kWh per capita)
# China                 CHN  Electric power consumption (kWh per capita)
#
#                  Indicator Code  1960  1961  1962  1963  1964  1965  1966  \
# Country Name
# India         EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# China         EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                  ...              2010         2011         2012         2013  \
# Country Name     ...
# India            ...        642.111615   698.547813   724.791188   765.563846
# China            ...       2943.589954  3298.003913  3474.988062  3773.405384
#
#                      2014  2015  2016  2017  2018  Unnamed: 63
# Country Name
# India          805.599191   NaN   NaN   NaN   NaN          NaN
# China         3927.044500   NaN   NaN   NaN   NaN          NaN
#
# [2 rows x 63 columns]

# %%
df.describe(include='all')
# Out:
#        Country Code                               Indicator Name  \
# count           264                                          264
# unique          264                                            1
# top             IRL  Electric power consumption (kWh per capita)
# freq              1                                          264
# mean            NaN                                          NaN
# std             NaN                                          NaN
# min             NaN                                          NaN
# 25%             NaN                                          NaN
# 50%             NaN                                          NaN
# 75%             NaN                                          NaN
# max             NaN                                          NaN
#
#            Indicator Code         1960         1961         1962         1963  \
# count                 264    31.000000    31.000000    31.000000    31.000000
# unique                  1          NaN          NaN          NaN          NaN
# top     EG.USE.ELEC.KH.PC          NaN          NaN          NaN          NaN
# freq                  264          NaN          NaN          NaN          NaN
# mean                  NaN  2178.066836  2306.604319  2467.409699  2659.852122
# std                   NaN  1689.237756  1777.325363  1928.007735  2078.485267
# min                   NaN    92.311060    96.920111   112.059857   120.583751
# 25%                   NaN  1099.938752  1219.208030  1336.931500  1497.937046
# 50%                   NaN  1814.676017  1882.223711  2006.770396  2124.359184
# 75%                   NaN  2535.743897  2743.948284  2837.871654  3040.462398
# max                   NaN  7681.140521  8404.620755  9390.978307  9658.705203
#
#                 1964          1965          1966     ...               2010  \
# count      31.000000     32.000000     32.000000     ...         183.000000
# unique           NaN           NaN           NaN     ...                NaN
# top              NaN           NaN           NaN     ...                NaN
# freq             NaN           NaN           NaN     ...                NaN
# mean     2899.021657   3014.253753   3174.577284     ...        3930.676754
# std      2333.155988   2469.020311   2544.706917     ...        5426.420735
# min       132.058238    143.835116    156.632887     ...          24.400935
# 25%      1622.975646   1656.117426   1774.050015     ...         645.176974
# 50%      2232.896504   2249.781885   2337.756267     ...        2307.331503
# 75%      3189.011902   3375.928885   3482.709560     ...        5376.477813
# max     10553.444067  11416.352955  11655.971257     ...       51439.908691
#
#                 2011          2012          2013          2014  2015  2016  \
# count     183.000000    184.000000    182.000000    182.000000   0.0   0.0
# unique           NaN           NaN           NaN           NaN   NaN   NaN
# top              NaN           NaN           NaN           NaN   NaN   NaN
# freq             NaN           NaN           NaN           NaN   NaN   NaN
# mean     3931.230989   3925.962073   3966.797431   3965.611052   NaN   NaN
# std      5376.675026   5406.534669   5479.691970   5428.809609   NaN   NaN
# min        31.148183     38.730820     39.812158     38.969149   NaN   NaN
# 25%       684.010242    719.359712    747.540057    776.774537   NaN   NaN
# 50%      2322.213342   2345.272523   2496.437138   2514.415633   NaN   NaN
# 75%      5430.628627   5234.925733   5191.646380   5112.797450   NaN   NaN
# max     52373.877009  53202.833660  54799.174708  53832.479092   NaN   NaN
#
#         2017  2018  Unnamed: 63
# count    0.0   0.0          0.0
# unique   NaN   NaN          NaN
# top      NaN   NaN          NaN
# freq     NaN   NaN          NaN
# mean     NaN   NaN          NaN
# std      NaN   NaN          NaN
# min      NaN   NaN          NaN
# 25%      NaN   NaN          NaN
# 50%      NaN   NaN          NaN
# 75%      NaN   NaN          NaN
# max      NaN   NaN          NaN
#
# [11 rows x 63 columns]

# %%
import numpy as np
df.dropna(subset=["1971"],axis=0).iloc[:,10:20]
# Out:
#                                                            1967         1968  \
# Country Name
# Angola                                                      NaN          NaN
# Albania                                                     NaN          NaN
# Arab World                                                  NaN          NaN
# United Arab Emirates                                        NaN          NaN
# Argentina                                                   NaN          NaN
# Australia                                           2969.488940  3102.006828
# Austria                                             2448.692544  2608.624238
# Belgium                                             2357.584930  2596.177718
# Benin                                                       NaN          NaN
# Bangladesh                                                  NaN          NaN
# Bulgaria                                                    NaN          NaN
# Bahrain                                                     NaN          NaN
# Bolivia                                                     NaN          NaN
# Brazil                                                      NaN          NaN
# Brunei Darussalam                                           NaN          NaN
# Canada                                              7630.168528  8030.418434
# Central Europe and the Baltics                              NaN          NaN
# Switzerland                                         3749.633874  3852.192111
# Chile                                                       NaN          NaN
# China                                                       NaN          NaN
# Cote d'Ivoire                                               NaN          NaN
# Cameroon                                                    NaN          NaN
# Congo, Dem. Rep.                                            NaN          NaN
# Congo, Rep.                                                 NaN          NaN
# Colombia                                                    NaN          NaN
# Costa Rica                                                  NaN          NaN
# Cuba                                                        NaN          NaN
# Curacao                                                     NaN          NaN
# Cyprus                                                      NaN          NaN
# Czech Republic                                              NaN          NaN
# ...                                                         ...          ...
# Sudan                                                       NaN          NaN
# Senegal                                                     NaN          NaN
# Singapore                                                   NaN          NaN
# El Salvador                                                 NaN          NaN
# Sub-Saharan Africa (excluding high income)                  NaN          NaN
# Sub-Saharan Africa                                          NaN          NaN
# Slovak Republic                                             NaN          NaN
# Sweden                                              6017.973467  6512.919865
# Syrian Arab Republic                                        NaN          NaN
# East Asia & Pacific (IDA & IBRD countries)                  NaN          NaN
# Togo                                                        NaN          NaN
# Thailand                                                    NaN          NaN
# Latin America & the Caribbean (IDA & IBRD count...          NaN          NaN
# Middle East & North Africa (IDA & IBRD countries)           NaN          NaN
# South Asia (IDA & IBRD)                                     NaN          NaN
# Sub-Saharan Africa (IDA & IBRD countries)                   NaN          NaN
# Trinidad and Tobago                                         NaN          NaN
# Tunisia                                                     NaN          NaN
# Turkey                                               170.269310   184.595870
# Tanzania                                                    NaN          NaN
# Upper middle income                                         NaN          NaN
# Uruguay                                                     NaN          NaN
# United States                                       5888.340915  6385.459329
# Venezuela, RB                                               NaN          NaN
# Vietnam                                                     NaN          NaN
# World                                                       NaN          NaN
# Yemen, Rep.                                                 NaN          NaN
# South Africa                                                NaN          NaN
# Zambia                                                      NaN          NaN
# Zimbabwe                                                    NaN          NaN
#
#                                                            1969         1970  \
# Country Name
# Angola                                                      NaN          NaN
# Albania                                                     NaN          NaN
# Arab World                                                  NaN          NaN
# United Arab Emirates                                        NaN          NaN
# Argentina                                                   NaN          NaN
# Australia                                           3329.609394  3609.978412
# Austria                                             2814.654642  3019.116159
# Belgium                                             2830.593969  3031.521046
# Benin                                                       NaN          NaN
# Bangladesh                                                  NaN          NaN
# Bulgaria                                                    NaN          NaN
# Bahrain                                                     NaN          NaN
# Bolivia                                                     NaN          NaN
# Brazil                                                      NaN          NaN
# Brunei Darussalam                                           NaN          NaN
# Canada                                              8532.908503  8962.202213
# Central Europe and the Baltics                              NaN          NaN
# Switzerland                                         4022.725425  4306.508607
# Chile                                                       NaN          NaN
# China                                                       NaN          NaN
# Cote d'Ivoire                                               NaN          NaN
# Cameroon                                                    NaN          NaN
# Congo, Dem. Rep.                                            NaN          NaN
# Congo, Rep.                                                 NaN          NaN
# Colombia                                                    NaN          NaN
# Costa Rica                                                  NaN          NaN
# Cuba                                                        NaN          NaN
# Curacao                                                     NaN          NaN
# Cyprus                                                      NaN          NaN
# Czech Republic                                              NaN          NaN
# ...                                                         ...          ...
# Sudan                                                       NaN          NaN
# Senegal                                                     NaN          NaN
# Singapore                                                   NaN          NaN
# El Salvador                                                 NaN          NaN
# Sub-Saharan Africa (excluding high income)                  NaN          NaN
# Sub-Saharan Africa                                          NaN          NaN
# Slovak Republic                                             NaN          NaN
# Sweden                                              7017.883373  7315.983573
# Syrian Arab Republic                                        NaN          NaN
# East Asia & Pacific (IDA & IBRD countries)                  NaN          NaN
# Togo                                                        NaN          NaN
# Thailand                                                    NaN          NaN
# Latin America & the Caribbean (IDA & IBRD count...          NaN          NaN
# Middle East & North Africa (IDA & IBRD countries)           NaN          NaN
# South Asia (IDA & IBRD)                                     NaN          NaN
# Sub-Saharan Africa (IDA & IBRD countries)                   NaN          NaN
# Trinidad and Tobago                                         NaN          NaN
# Tunisia                                                     NaN          NaN
# Turkey                                               205.547667   222.386186
# Tanzania                                                    NaN          NaN
# Upper middle income                                         NaN          NaN
# Uruguay                                                     NaN          NaN
# United States                                       6904.833800  7236.657043
# Venezuela, RB                                               NaN          NaN
# Vietnam                                                     NaN          NaN
# World                                                       NaN          NaN
# Yemen, Rep.                                                 NaN          NaN
# South Africa                                                NaN          NaN
# Zambia                                                      NaN          NaN
# Zimbabwe                                                    NaN          NaN
#
#                                                            1971         1972  \
# Country Name
# Angola                                                80.262510    88.515108
# Albania                                              532.028432   568.403202
# Arab World                                           195.163395   209.787297
# United Arab Emirates                                 677.885857  1307.248467
# Argentina                                            870.623730   920.471571
# Australia                                           3751.642576  3880.928891
# Austria                                             3213.126836  3404.469208
# Belgium                                             3217.045264  3612.355533
# Benin                                                 10.750622    11.828227
# Bangladesh                                            10.688788    10.503352
# Bulgaria                                            2292.653983  2486.066090
# Bahrain                                             1951.777479  1963.736336
# Bolivia                                              165.196167   173.475011
# Brazil                                               458.727889   497.625420
# Brunei Darussalam                                   1753.532853  1675.195146
# Canada                                              9300.717215  9903.776234
# Central Europe and the Baltics                      2088.953932  2243.537338
# Switzerland                                         4615.348218  4776.267394
# Chile                                                776.690939   802.212494
# China                                                151.989347   163.911929
# Cote d'Ivoire                                         94.354464   101.267482
# Cameroon                                             152.140758   155.340303
# Congo, Dem. Rep.                                     162.282834   158.805765
# Congo, Rep.                                           54.740257    55.842120
# Colombia                                             403.635488   389.470632
# Costa Rica                                           604.732506   650.728693
# Cuba                                                 505.751942   514.996731
# Curacao                                             4091.214405  4312.504231
# Cyprus                                               990.563075  1133.754351
# Czech Republic                                      3424.202043  3595.796844
# ...                                                         ...          ...
# Sudan                                                 26.079658    27.405174
# Senegal                                               73.830033    74.694251
# Singapore                                           1154.810923  1371.027690
# El Salvador                                          169.713633   181.774351
# Sub-Saharan Africa (excluding high income)           318.249252   341.361888
# Sub-Saharan Africa                                   318.249252   341.361888
# Slovak Republic                                     2696.684044  2829.469119
# Sweden                                              7674.294491  8131.933073
# Syrian Arab Republic                                 176.232720   201.613467
# East Asia & Pacific (IDA & IBRD countries)           133.102689   144.003640
# Togo                                                  64.053820    61.399317
# Thailand                                             120.321586   140.238617
# Latin America & the Caribbean (IDA & IBRD count...   497.856135   528.997643
# Middle East & North Africa (IDA & IBRD countries)    198.131363   212.746666
# South Asia (IDA & IBRD)                               87.303121    89.269052
# Sub-Saharan Africa (IDA & IBRD countries)            318.249252   341.361888
# Trinidad and Tobago                                 1036.214169  1145.817097
# Tunisia                                              155.238347   175.128599
# Turkey                                               246.300675   276.407954
# Tanzania                                              30.186908    31.985404
# Upper middle income                                  293.073401   315.540602
# Uruguay                                              732.009353   695.744264
# United States                                       7517.304646  8076.409269
# Venezuela, RB                                       1033.942169  1092.423932
# Vietnam                                               40.327377    37.673315
# World                                               1199.344307  1272.731792
# Yemen, Rep.                                           33.171686    33.555502
# South Africa                                        2161.921572  2303.490327
# Zambia                                              1021.597370  1070.494945
# Zimbabwe                                             665.271963   844.672404
#
#                                                             1973  \
# Country Name
# Angola                                                101.402041
# Albania                                               593.446746
# Arab World                                            228.947273
# United Arab Emirates                                 1689.435864
# Argentina                                             956.277673
# Australia                                            4230.343797
# Austria                                              3620.562040
# Belgium                                              3941.603741
# Benin                                                  18.627506
# Bangladesh                                             15.169341
# Bulgaria                                             2683.109679
# Bahrain                                              2087.447344
# Bolivia                                               173.387192
# Brazil                                                552.872244
# Brunei Darussalam                                    1581.852450
# Canada                                              10297.947983
# Central Europe and the Baltics                       2389.988868
# Switzerland                                          5010.188911
# Chile                                                 770.579703
# China                                                 175.933737
# Cote d'Ivoire                                         111.242992
# Cameroon                                              152.819809
# Congo, Dem. Rep.                                      167.364102
# Congo, Rep.                                            60.826966
# Colombia                                              420.832470
# Costa Rica                                            674.936603
# Cuba                                                  547.403175
# Curacao                                              4478.871706
# Cyprus                                               1218.684608
# Czech Republic                                       3729.994741
# ...                                                          ...
# Sudan                                                  32.300456
# Senegal                                                80.181046
# Singapore                                            1599.179207
# El Salvador                                           203.874216
# Sub-Saharan Africa (excluding high income)            358.827935
# Sub-Saharan Africa                                    358.827935
# Slovak Republic                                      3026.212742
# Sweden                                               8745.485670
# Syrian Arab Republic                                  182.299966
# East Asia & Pacific (IDA & IBRD countries)            156.172175
# Togo                                                   55.571354
# Thailand                                              161.459118
# Latin America & the Caribbean (IDA & IBRD count...    563.724212
# Middle East & North Africa (IDA & IBRD countries)     238.681840
# South Asia (IDA & IBRD)                                90.885161
# Sub-Saharan Africa (IDA & IBRD countries)             358.827935
# Trinidad and Tobago                                  1124.576630
# Tunisia                                               191.661787
# Turkey                                                297.339651
# Tanzania                                               33.566607
# Upper middle income                                   339.815779
# Uruguay                                               705.153396
# United States                                        8573.194154
# Venezuela, RB                                        1144.973925
# Vietnam                                                39.330775
# World                                                1346.434661
# Yemen, Rep.                                            31.578373
# South Africa                                         2411.225946
# Zambia                                               1117.638952
# Zimbabwe                                              866.415554
#
#                                                             1974  \
# Country Name
# Angola                                                123.355406
# Albania                                               591.032643
# Arab World                                            253.176038
# United Arab Emirates                                 1860.557870
# Argentina                                             986.176142
# Australia                                            4578.882169
# Austria                                              3769.029711
# Belgium                                              4134.390881
# Benin                                                  16.941644
# Bangladesh                                             16.856404
# Bulgaria                                             2842.231221
# Bahrain                                              2282.552171
# Bolivia                                               181.348334
# Brazil                                                602.887424
# Brunei Darussalam                                    1540.851917
# Canada                                              10820.675270
# Central Europe and the Baltics                       2522.681552
# Switzerland                                          5027.119384
# Chile                                                 813.183448
# China                                                 174.233354
# Cote d'Ivoire                                         113.714094
# Cameroon                                              169.412836
# Congo, Dem. Rep.                                      169.292807
# Congo, Rep.                                            61.580745
# Colombia                                              459.269265
# Costa Rica                                            717.644873
# Cuba                                                  571.743075
# Curacao                                              4576.982966
# Cyprus                                               1043.062931
# Czech Republic                                       3860.355236
# ...                                                          ...
# Sudan                                                  37.235530
# Senegal                                                79.752654
# Singapore                                            1634.227285
# El Salvador                                           216.098180
# Sub-Saharan Africa (excluding high income)            375.280067
# Sub-Saharan Africa                                    375.280067
# Slovak Republic                                      3138.205353
# Sweden                                               8786.445513
# Syrian Arab Republic                                  210.759673
# East Asia & Pacific (IDA & IBRD countries)            154.965981
# Togo                                                   71.712816
# Thailand                                              165.755621
# Latin America & the Caribbean (IDA & IBRD count...    600.100524
# Middle East & North Africa (IDA & IBRD countries)     260.653214
# South Asia (IDA & IBRD)                                94.297128
# Sub-Saharan Africa (IDA & IBRD countries)             375.280067
# Trinidad and Tobago                                  1155.404978
# Tunisia                                               205.545234
# Turkey                                                312.455687
# Tanzania                                               33.791437
# Upper middle income                                   352.979765
# Uruguay                                               702.886509
# United States                                        8449.928456
# Venezuela, RB                                        1201.090501
# Vietnam                                                33.884598
# World                                                1345.771375
# Yemen, Rep.                                            36.027565
# South Africa                                         2529.898191
# Zambia                                               1182.750982
# Zimbabwe                                              901.207797
#
#                                                             1975          1976
# Country Name
# Angola                                                127.432825     55.562608
# Albania                                               739.345093    908.674547
# Arab World                                            280.426799    323.230395
# United Arab Emirates                                 2296.490861   2790.044873
# Argentina                                            1004.182495   1024.203812
# Australia                                            4781.616641   4901.589111
# Austria                                              3734.445473   4068.190905
# Belgium                                              3887.477425   4247.406380
# Benin                                                  18.069531     19.419373
# Bangladesh                                             16.983161     17.274177
# Bulgaria                                             3035.636188   3247.551349
# Bahrain                                              2626.217909   3171.783811
# Bolivia                                               189.249623    199.420567
# Brazil                                                649.099869    719.315698
# Brunei Darussalam                                    1478.310891   1420.724748
# Canada                                              10436.942565  11043.838762
# Central Europe and the Baltics                       2683.047695   2848.027630
# Switzerland                                          4878.812968   5082.900384
# Chile                                                 742.175724    779.959245
# China                                                 199.039715    204.030365
# Cote d'Ivoire                                         122.264761    135.346300
# Cameroon                                              174.726666    165.852940
# Congo, Dem. Rep.                                      167.231973    161.848487
# Congo, Rep.                                            64.149370     66.546964
# Colombia                                              441.653348    456.178762
# Costa Rica                                            729.948932    765.513501
# Cuba                                                  623.196074    671.187983
# Curacao                                              4640.277880   4665.359206
# Cyprus                                               1029.618856   1139.104594
# Czech Republic                                       4031.268703   4173.440113
# ...                                                          ...           ...
# Sudan                                                  38.411327     39.036134
# Senegal                                                83.059692     86.481381
# Singapore                                            1728.100415   1884.620416
# El Salvador                                           210.245870    240.112744
# Sub-Saharan Africa (excluding high income)            390.674357    405.853557
# Sub-Saharan Africa                                    390.674357    405.853557
# Slovak Republic                                      3111.768994   3260.460837
# Sweden                                               9051.519102   9751.545981
# Syrian Arab Republic                                  236.473943    229.772632
# East Asia & Pacific (IDA & IBRD countries)            175.105201    180.395118
# Togo                                                   74.260116     69.792307
# Thailand                                              183.819734    206.721665
# Latin America & the Caribbean (IDA & IBRD count...    620.481907    662.662331
# Middle East & North Africa (IDA & IBRD countries)     285.232383    314.251388
# South Asia (IDA & IBRD)                               103.102887    110.496782
# Sub-Saharan Africa (IDA & IBRD countries)             390.674357    405.853557
# Trinidad and Tobago                                  1133.970677   1263.579088
# Tunisia                                               214.950050    239.371988
# Turkey                                                358.579432    420.582375
# Tanzania                                               34.229643     34.862631
# Upper middle income                                   384.899756    409.161445
# Uruguay                                               762.144492    806.284443
# United States                                        8522.394003   8968.775655
# Venezuela, RB                                        1214.131860   1276.790064
# Vietnam                                                38.867713     46.297717
# World                                                1354.623969   1425.536721
# Yemen, Rep.                                            37.624299     42.786872
# South Africa                                         2642.489310   2770.927481
# Zambia                                               1150.089500   1166.173383
# Zimbabwe                                              975.738181   1037.680516
#
# [149 rows x 10 columns]

# %%
df1=df.reset_index()
for i in range(1,40):
    df1.years[i].value_counts_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-241a3aea195d> in <module>()
#       1 df1=df.reset_index()
#       2 for i in range(1,40):
# ----> 3     df1.years[i].value_counts_
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'years'

# %%
years[1]
# Out:
# '1961'

# %%
df1.describe().iloc[:,40:50]
# Out:
#                2000          2001          2002          2003          2004  \
# count    182.000000    182.000000    182.000000    182.000000    182.000000
# mean    3324.934832   3372.146624   3437.489439   3511.521819   3576.806504
# std     4455.639160   4505.147990   4551.679165   4546.163632   4586.875305
# min       22.648940     26.440945     26.100330     28.478819     28.072706
# 25%      510.063872    520.142928    525.528405    561.790161    584.348600
# 50%     1592.002467   1620.444012   1696.794028   1768.189974   1887.161455
# 75%     4455.795222   4398.856444   4495.350313   4846.718164   4772.288615
# max    26201.525577  26950.394430  27896.898683  27666.386894  28215.452248
#
#                2005          2006          2007          2008          2009
# count    183.000000    183.000000    183.000000    183.000000    183.000000
# mean    3655.550523   3741.314480   3814.325402   3878.891042   3771.897746
# std     4624.919800   4731.997086   4910.276123   5389.385340   5299.524305
# min       33.365011     34.885209     25.322048     23.596014     35.725631
# 25%      606.579655    664.162373    675.739119    626.478542    620.646092
# 50%     1999.631947   2063.097317   2047.149308   2040.760435   2099.596260
# 75%     5037.465396   5230.143155   5412.409211   5439.247474   5183.744477
# max    27988.029683  31328.386804  36852.544886  50063.954331  51259.187627
